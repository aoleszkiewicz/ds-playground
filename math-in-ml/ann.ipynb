# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X, y = make_regression(
    n_samples=100, n_features=5, n_informative=5, n_targets=1, coef=False
)

# %%
data = pd.DataFrame(X)

# %%
print(data.shape)
data.head()
# Out:
# (100, 5)
#           0         1         2         3         4
# 0  1.097833  0.617718  0.903200  0.647267  0.229947
# 1  1.848591 -0.351059 -0.288792 -0.150355 -0.966560
# 2 -0.758498  0.662550 -0.587571 -0.816694 -0.121870
# 3  0.583810  0.559323 -0.176462  1.071328 -0.939873
# 4  1.562368  0.298571 -0.126443 -1.286386  0.084757

# %%
data.describe()
# Out:
#                 0           1           2           3           4
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.030564    0.179555   -0.190744    0.055662    0.097380
# std      0.912987    0.899794    0.949610    0.948652    1.015130
# min     -2.096148   -2.415246   -3.316192   -2.975100   -2.322990
# 25%     -0.552627   -0.448365   -0.872786   -0.553803   -0.520513
# 50%      0.011444    0.320208   -0.082936    0.133158    0.059996
# 75%      0.651701    0.765323    0.480380    0.711806    0.782458
# max      2.849486    2.513652    1.930155    1.882710    2.675305

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
corr = data.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# pca i scatterplot?
