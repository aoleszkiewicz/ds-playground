# %%
import pandas as pd

# %%
platform_stats_df = pd.read_csv("./data/raw/platform_statistics_2026.csv")
user_behavior_df = pd.read_csv("./data/raw/social_media_user_behavior.csv")

# %%
platform_stats_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   platform                       17 non-null     str
#  1   monthly_active_users_billions  17 non-null     float64
#  2   year_over_year_growth_pct      17 non-null     float64
#  3   avg_daily_time_minutes         17 non-null     int64
#  4   primary_age_group              17 non-null     str
#  5   primary_content_format         17 non-null     str
#  6   avg_engagement_rate_pct        17 non-null     float64
#  7   social_commerce_adoption_pct   17 non-null     float64
#  8   headquarters_country           17 non-null     str
#  9   founded_year                   17 non-null     int64
#  10  data_source                    17 non-null     str
# dtypes: float64(4), int64(2), str(5)
# memory usage: 1.6 KB

# %%
user_behavior_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 45 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   user_id                             25000 non-null  str
#  1   age                                 25000 non-null  int64
#  2   age_group                           25000 non-null  str
#  3   gender                              25000 non-null  str
#  4   country                             25000 non-null  str
#  5   occupation                          25000 non-null  str
#  6   education_level                     25000 non-null  str
#  7   income_bracket                      25000 non-null  str
#  8   relationship_status                 25000 non-null  str
#  9   primary_platform                    25000 non-null  str
#  10  num_platforms_used                  25000 non-null  int64
#  11  daily_screen_time_minutes           25000 non-null  int64
# ...

# %%
platform_stats_df['monthly_active_users_billions'].describe()
# Out:
# count    17.000000
# mean      1.229412
# std       1.078387
# min       0.040000
# 25%       0.330000
# 50%       0.930000
# 75%       1.990000
# max       3.070000
# Name: monthly_active_users_billions, dtype: float64

# %%
quantiles = platform_stats_df['monthly_active_users_billions'].quantile([0.25, 0.75])

iqr = quantiles.iloc[1] - quantiles.iloc[0]
print('IQR:', iqr)
# Out:
# IQR: 1.66

# %%
bins = pd.cut(x=platform_stats_df['monthly_active_users_billions'], bins=10)
display(bins)
# Out:
# 0      (2.767, 3.07]
# 1      (2.767, 3.07]
# 2     (2.464, 2.767]
# 3      (2.767, 3.07]
# 4     (1.858, 2.161]
# 5     (1.252, 1.555]
# 6     (0.949, 1.252]
# 7     (0.646, 0.949]
# 8     (0.646, 0.949]
# 9     (0.646, 0.949]
# 10    (0.343, 0.646]
# 11    (0.343, 0.646]
# 12    (0.037, 0.343]
# 13    (0.037, 0.343]
# 14    (0.037, 0.343]
# 15    (0.037, 0.343]
# 16    (0.037, 0.343]
# Name: monthly_active_users_billions, dtype: category
# Categories (10, interval[float64, right]): [(0.037, 0.343] < (0.343, 0.646] < (0.646, 0.949] < (0.949, 1.252] ... (1.858, 2.161] < (2.161, 2.464] < (2.464, 2.767] < (2.767, 3.07]]

# %%
# import matplotlib.pyplot as plt

platform_stats_df['monthly_active_users_billions'].plot.box()
# Out:
# <Axes: >
